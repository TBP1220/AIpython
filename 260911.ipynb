# %%
print("2주차 코딩")
# Out:
# 2주차 코딩

# %%
a="2주차 코딩"
print(a)
# Out:
# 2주차 코딩

# %%
print(1+2)
# Out:
# 3

# %%
x=1
y=2
print(x+y)
# Out:
# 3

# %%
print(x+y)
print(x-y)
print(x*y)
print(x/y)
# Out:
# 3
# -1
# 2
# 0.5

# %%
#두 자연수 10과 5가 주어진다.
#이때, A+B, A-B, A/B(몫), A%B(나머지)를 출력하는 프로그램을 작성하시오.

A=10
B=5
print(A+B)
print(A-B)
print(A/B)
print(A%B)
# Out:
# 15
# 5
# 2.0
# 0

# %% [markdown]
# 가로 12, 세로 7인 직사각형의 넓이와 둘레를 구하시오.

# %%
W=12
H=7
print(W*H)
print(2*(W+H))
# Out:
# 84
# 38

# %% [markdown]
# 국어 88, 영어 92, 수학 75점인 학생의 과목 평균을 구하시오.

# %%
K=88
E=92
M=75
print((K+E+M)/3)
# Out:
# 85.0
